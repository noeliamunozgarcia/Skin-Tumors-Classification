# %% [markdown]
# ## Model Demo

# %%
import torch
import matplotlib.pyplot as plt

from tkinter import Tk
from tkinter.filedialog import askopenfilename

from PIL import Image

from src.model.predict import ModelPredict
from src.utils.config import Config

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
MODEL_PATH = Config.get_path('model')

# %%
image_path='C:/Users/UX534/ISIC-2019-v2/data/images/ISIC_0026716.jpg'

# %%
image = Image.open(image_path)

model = ModelPredict(DEVICE, 'C:/Users/UX534/ISIC-2019-v2/models/model_weights.pth')
model.load()
y_pred, confidence = model.predict(image)

# %%
LABELS = {
    0: 'BENIGN-TUMOR',
    1: 'MALIGNANT-TUMOR',
}

plt.imshow(image)
print('The Predicted Label is [%s] with Confidence [%.4f]' % (LABELS[y_pred], confidence))
# Out:
# The Predicted Label is [MALIGNANT-TUMOR] with Confidence [0.9560]
